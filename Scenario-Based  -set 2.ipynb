# %%
# Scenario: You are developing a banking application that categorizes transactions based on the amount entered.
# Write logic to determine whether the amount is positive, negative, or zero.

amount = int(input("Enter the amount: "))

if amount > 0:
    print("Positive (Amount of Rupees",amount," Creditted to your Account)")
elif amount < 0:
    print("Positive (Amount of Rupees",amount,"Debitted from your Account)")
else:
    print("Zero transactions made")
# Out:
# Enter the amount:  -500
# Positive (Amount of Rupees -500 Debitted from your Account)

# %%
# 2.	Scenario: A digital locker requires users to enter a numerical passcode. 
# As part of a security feature, the system checks the sum of the digits of the passcode.
# Write logic to compute the sum of the digits of a given number.
pin = input("Enter your numerical passcode: ")
digits = [int(digit) for digit in pin]
sum_of_digits = 0
for digit in digits:
    sum_of_digits += digit
print("Sum of digits:", sum_of_digits)
# Out:
# Enter your numerical passcode:  0364
# Sum of digits: 13

# %%
# 3.	Scenario: A mobile payment app uses a simple checksum validation where reversing a transaction ID helps detect fraud.
# Write logic to take a number and return its reverse.

num = int(input("enter the number: "))
num1 = str(num)
rev= num1[::-1]
rev_num = int(rev)
print(rev_num)
# Out:
# enter the number:  15079698
# 89697051

# %%
# 4.	Scenario: In a secure login system, certain features are enabled only for users with prime-numbered user IDs.
# Write logic to check if a given number is prime.

login = int(input("Please enter your 6 digit login id: "))
if login <99999:
    print("Invalid Pin")
else:
    is_prime=True
    
    for i in range(2, login):
        if login %i == 0:
            is_prime = False
            break
    if is_prime:
        print("Access Granted")
    else:
        print("Invalid Pin, Access Denied")
# Out:
# Please enter your 6 digit login id:  100019
# Access Granted

# %%
#5.	Scenario: A scientist is working on permutations and needs to calculate the factorial of numbers frequently.
# Write logic to find the factorial of a given number using recursion.

number = int(input("Enter the number to find it's factorial"))
def factorial(n):
    if n==0 or n==1:
        return 1
    else:
        return n * factorial(n-1)
result = factorial(number)
print("Factorial of", number, "is:", factorial(number))
# Out:
# Enter the number to find it's factorial 5
# Factorial of 5 is: 120

# %%
# 6.	Scenario: A unique lottery system assigns ticket numbers where only Armstrong numbers win the jackpot.
# Write logic to check whether a given number is an Armstrong number.

num = input("Enter the lottery ticket number: ")
num_digits = len(num)
sum_of_powers = sum(int(digit) ** num_digits for digit in num)
if sum_of_powers == int(num):
    print(num, "Jackpot")
else:
    print(num, "Better Luck Next Time")
# Out:
# Enter the lottery ticket number:  153
# 153 Jackpot

# %%
# 7.	Scenario: A password manager needs to strengthen weak passwords by swapping the first and last characters of user-generated passwords.
# Write logic to perform this operation on a given string.

password = input("Enter the password: ")
strlen = len(password)
if strlen <6:
    print(password)
else:
    swap=password[-1]+password[1:-1]+password[0]
    print(swap)
# Out:
# Enter the password:  Akshaya
# akshayA

# %%
# 8.	Scenario: A low-level networking application requires decimal numbers to be converted into binary format before transmission.
# Write logic to convert a given decimal number into its binary equivalent.

num = int(input("Enter the decimal value: "))
binfun = " "
while num > 0:
    remainder = num %2
    binfun += str(remainder)
    num = num //2
binfun = binfun [::-1]
print("Binary Representation is: ",binfun)
# Out:
# Enter the decimal value:  10
# Binary Representation is:  1010

# %%
# 9.	Scenario: A text-processing tool helps summarize articles by identifying the most significant words.
# Write logic to find the longest word in a sentence.


sentence = input("Enter your sentence: ")
words = sentence.split()
longest_word = ""
for word in words:
    if len(word)>len(longest_word):
        longest_word = word
print("Longest Word is: ", longest_word)
# Out:
# Enter your sentence:  Hello world, you're beautiful
# Longest Word is:  beautiful

# %%
# 10.	Scenario: A plagiarism detection tool compares words from different documents and checks if they are anagrams (same characters but different order).
# Write logic to check whether two given strings are anagrams.

name1 = input("Enter your first name: ")
name2 = input("Enter your last name: ")

name1 = name1.replace(" ", "").lower()
name2 = name2.replace(" ", "").lower()

sort1 = sorted(name1)
sort2 = sorted(name2)

if sort1 == sort2:
    print("It's an Anagram")
else:
    print("Not an Anagram")
# Out:
# Enter your first name:  Ananth
# Enter your last name:  Akshay
# Not an Anagram
