# %%
#print statement
print ("Hope Ai")
# Out:
# Hope Ai

# %%
#Buy Input
insname = input("Enter Your Insititute Name: ")
print(insname)
# Out:
# Enter Your Insititute Name:  Hope Ai
# Hope Ai

# %%
name = input("Enter your Name: ")
age = int(input("Enter your Age: "))
college = input("Enter your college name")
degree = input("Enter your Degree: ")
print(name)
print(age)
print(college)
print(degree)
# Out:
# Enter your Name:  Akshay
# Enter your Age:  26
# Enter your college name NGP
# Enter your Degree:  CT
# Akshay
# 26
# NGP
# CT

# %%
#Addition
a=50
b=40
print(a+b)
# Out:
# 90

# %%
#Subtraction
a=90
b=50
print(a-b)
# Out:
# 40

# %%
#Multiplication
a=89
b=69
print(a*b)
# Out:
# 6141

# %%
#Division
a=100
b=100
print(a/b)
# Out:
# 1.0

# %%
#Floor Division
a=100
b=100
print(int(a/b))
# Out:
# 1

# %%
#Modulo
a=76
b=31
print(a%b)
# Out:
# 14

# %%
#Power
a=4
b=4
print(a**b)
# Out:
# 256
