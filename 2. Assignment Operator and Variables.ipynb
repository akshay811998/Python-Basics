# %%
num1=10
num2=40
add=num1+num2
print(add)
# Out:
# 50

# %%
num1=int(input("Enter the num1 : "))
num2=int(input("Enter the num2 : "))
add=(num1+num2)
print(add)
# Out:
# Enter the num1 :  50
# Enter the num2 :  30
# 80
