# %%
#1.Find the error in the following Python code:

for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#2.What will be the output of this code?

a = 10
b = "5"
print(a + b)

ERROR --- Int and Str cannot be operated together
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       3 a = 10
#       4 b = "5"
# ----> 5 print(a + b)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#3.What is the issue in this Python snippet?

def add_numbers(a, b):
    return a + b
add_numbers(1, 2)
#Ans: Unwanted spaces and missing : in def():
# Out:
# 3

# %%
#4.Identify the bug in the following Python code:

numbers = [1, 2, 3, 4]
print(numbers)

#Ans: Unwanted space and in print statement range is invalid
# Out:
# [1, 2, 3, 4]

# %%
#5.Find the error in the following Python code:
print ("Hello, World!")
#Ans: Missing open and closed brackets after print (parantheses)
# Out:
# Hello, World!

# %%
#6.Find the error in the following Python code:
x = 5 / 0

#Ans: Can't be divided by 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[17], line 2
#       1 #6.Find the error in the following Python code:
# ----> 2 x = 5 / 0
#       3 print(x)
#
# ZeroDivisionError: division by zero

# %%
#7.Find the error in the following Python code:
name = "Alice"
age = "25"
print("Name: " + name + ", Age: " + age)

#Ans: Error - 1: name = "Alice" is in the comment, Error - 2: integer can't be concantenated while printing (Either int should be converted into string as "25") or (+int(age))
# Out:
# Name: Alice, Age: 25

# %%
#8.Find the error
for i in range(1, 10, -1):
    print(i)

# %%
#9. Find the error in the following Python code:
x = 10
if x = 5:
    print("x is 5")

# %%
#10. Identify the error in the following function definition:

def greet(name):
    print("Hello, " + name)
greet(name)
# Out:
# Hello, Alice
