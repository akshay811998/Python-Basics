# %%
#1. Basic Print Statement
print("Welcome to Assignment 1")
# Out:
# Welcome to Assignment 1

# %%
#2. Sum
num1=10
num2=30
add=(num1+num2)
print(add)
# Out:
# 40

# %%
#3. BMI
bmi=float(input("Enter your BMI value"))
if (bmi<18.5):
    print(bmi,"Underweight")
elif (bmi<24.9):
    print(bmi,"Healthy Weight")
elif (bmi<29.9):
    print(bmi,"Over Weight")
else:
    print(bmi,"You're Obese")
# Out:
# Enter your BMI value 29.7
# 29.7 Over Weight
