# %%
#1. Scenario: A system checks if a user is eligible to vote based on their age. 
# Write logic to ask the user for their age and determine if they are eligible to vote based on whether they are 18 or older.


age = int(input("Enter your age: "))
if age < 18:
    print ("You're not eligible to vote")
else:
    print("You're Eligible")
# Out:
# Enter your age:  25
# You're Eligible

# %%
# 2. Scenario: A program processes a list of numbers and needs to find the largest value.

numbers = [5,10,15,20,25,30,29]
large = numbers[0]
for num in numbers:
    if num > large:
        large = num
print("The Largest Value: ", large)
# Out:
# The Largest Value:  30

# %%
# 3.	Scenario: A company provides employees with a 10% bonus if their salary exceeds $50,000.
# Write logic to determine the bonus amount based on the given salary.

salary = int(input("Enter your Salary: "))

if salary < 50000:
    print("You're not eligible for bonus")
else:
    print("Congratulations, you're eligible to claim a bonus of: ",salary*10/100)
# Out:
# Enter your Salary:  50000
# Congratulations, you're eligible to claim a bonus of:  5000.0

# %%
# 4.	Scenario: A program evaluates a number to determine if it is even or odd.
# Write logic to check whether a given number is even or odd.


num = int(input("Enter the number: "))
if num < 1:
    print("Enter the number from 1")
else:
    if (num%2 == 0):
        print("The number is even")
    else:
        print("The number is odd")
# Out:
# Enter the number:  2
# The number is even

# %%
# 5.	Scenario: A text-processing tool reverses a given word or sentence for formatting purposes.
# Write logic to take a word or sentence as input and produce its reversed version.

text = input("Enter a sentence or a word: ")
reverse = text[::-1]
print(reverse)
# Out:
# Enter a sentence or a word:  yahskA
# Akshay

# %%
# 6.	Scenario: A grading system determines whether a student has passed or failed based on their score.
# Write logic to check if a student has passed a subject by scoring at least 40 marks.

def marks():
    marks = int(input("Enter your mark: "))
    if marks <40:
        print("Fail")
    else:
        print("Pass")
marks()
# Out:
# Enter your mark:  80
# Pass

# %%
# 7.	Scenario: A retail store offers a 20% discount if a customer’s total order exceeds $100.
# Write logic to calculate the final amount to be paid after applying the discount.

cost = int(input("Enter the cart value: "))
discount = (cost)*20/100
if cost<100:
    print ("You're not eligible for discount")
else:
    print("You're eligible for the discount of: USD", discount)
    print("You're final amount to paid after applying discount is: USD",cost-discount)
# Out:
# Enter the cart value:  120
# You're eligible for the discount of: USD 24.0
# You're final amount to paid after applying discount is: USD 96.0

# %%
# 8.	Scenario: A banking system processes withdrawal requests and ensures the user has enough balance.
# Write logic to check if a user has enough balance before allowing a withdrawal and update the remaining balance accordingly.

amount = int(input("Enter the amount for withdrawl: "))
def withdrawl():
    if amount < 10000:
        print("You're request for withdrawl has been approved")
        print("Remaining balance in your account is: ",10000-amount)
    else:
        print("You're requested amount is greater than the available balance of 10000 in your account and withdrawl request has been denied")
withdrawl()
# Out:
# Enter the amount for withdrawl:  10001
# You're requested amount is greater than the available balance of 10000 in your account and withdrawl request has been denied

# %%
# 9.	Scenario: A calendar system verifies whether a given year is a leap year based on standard leap year rules.
# Write logic to determine whether a given year is a leap year.

year = int(input("Enter the year: "))
if year %100 ==0:
    print ("Not a leap year")
elif year % 4 == 0:
    print ("Leap Year")
elif year % 400 == 0:
    print ("Leap Year")
else:
    print("Not a leap year")
# Out:
# Enter the year:  2026
# Not a leap year

# %%
# 10.	Scenario: A program filters out only even numbers from a given list.
# Write logic to extract and return only the even numbers from a list.

numbers = [1,2,3,8,23,25,28,32,48]
even_numbers = []
for num in numbers:
    if num%2 == 0:
        even_numbers.append(num)
print(even_numbers)
# Out:
# [2, 8, 28, 32, 48]
