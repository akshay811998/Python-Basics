# %%
from ClassFunctions import classandfunctions

# %%
classandfunctions.subFields()
# Out:
# Sub-fields in AI are as below:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# NLP

# %%
classandfunctions.oddEven()
# Out:
# Enter the number:  5
# 5 -The given number is ODD Number

# %%
classandfunctions.Elegible()
# Out:
# Please enter your gender (M/F):  M
# Enter your Age:  19
# Not Eligible

# %%
classandfunctions.percentage()
# Out:
# Enter your marks in Math:  100
# Enter your marks in Science:  87
# Enter your marks in Social Studies:  75
# Enter your marks in English:  97
# Enter your marks in Tamil:  90
# You're total marks in 10th board exam is 449
# You're percentage in 10th board exam is: 89.8

# %%
classandfunctions.area()
# Out:
# Enter the height of the triangle:  10
# Enter the breadth of the triangle:  3
# The area of triangle is: 15.0

# %%
classandfunctions.perimeter()
# Out:
# Enter the length of the triangle:  4
# Enter the breadth of the triangle:  1
# Enter the height of the triangle:  2
# The perimeter of triangle is: 7
